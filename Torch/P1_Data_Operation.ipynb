# %% [markdown]
# N维数组是机器学习和神经网络的主要数据结构
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 创建数组
#     创建数组需要：
#         形状：例如3 x 4矩阵
#         每个元素的数据类型：例如32位浮点数
#         每个元素的值：例如全是0，或随机数
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 访问元素
# ![image.png](attachment:image.png)
